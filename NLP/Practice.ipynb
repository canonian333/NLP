# %%
pip install pandas numpy seaborn matplotlib
# Out:
# ...
#   Using cached numpy-2.3.5-cp312-cp312-win_amd64.whl.metadata (60 kB)
# ...
#   Using cached matplotlib-3.10.7-cp312-cp312-win_amd64.whl.metadata (11 kB)
# ...
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#   Using cached contourpy-1.3.3-cp312-cp312-win_amd64.whl.metadata (5.5 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached fonttools-4.60.1-cp312-cp312-win_amd64.whl.metadata (114 kB)
# ...
#   Using cached kiwisolver-1.4.9-cp312-cp312-win_amd64.whl.metadata (6.4 kB)
# ...
#   Using cached pillow-12.0.0-cp312-cp312-win_amd64.whl.metadata (9.0 kB)
# ...
#   Using cached pyparsing-3.2.5-py3-none-any.whl.metadata (5.0 kB)
# ...
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------- 0.1/11.0 MB 2.2 MB/s eta 0:00:05
#    - -------------------------------------- 0.5/11.0 MB 5.6 MB/s eta 0:00:02
# ...

# %%
A = [
    "Hey, can you call me later? My number changed — it's 9876543210.",
    "The office landline is (044) 2653-8899.",
    "Please register using your phone: +91-98765-43210.",
    "My WhatsApp is +1 202 555 0199.",
    "The courier guy called from 080-2244-5531.",
    "Contact my assistant: (123)-456-7890.",
    "Backup phone: 123.456.7890",
    "Shipment confirmation mailed to order-567@shopmart.com.",
    "Ping me on harish007@gmail.com.",
    "Official contact: info@digitalhub.ai.",
    "Here’s the temp login mail — temp_user01@domain.co.",
    "Their support line is (555) 012-3456.",
    "My new SIM is 091-234-567-8901.",
    "Billing queries → billing@streamflix.cc.",
    "My alternate number is +971 50 123 4567.",
    "The delivery partner texted from +33 6 12 34 56 78.",
    "Tech support guy called using 555 867 5309.",
    "For collaboration, reach me at creator.vibes@inbox.art.",
    "My old number 98989 98989 still works.",
    "They sent the verification to vCode-9982@secure.com."
]

B = [
    "Sure, or email me at samuel_98@example.com.",
    "Got it. Send the report to reports.hr@workmail.co.",
    "And they want an alternate mail ID like rahul.k@company.org.",
    "You can reach me at jenny.morris23@outlook.com.",
    "Write to support at helpdesk@flipzap.in if there's an issue.",
    "Oh cool. My email is lucia-perez@mailbox.net if needed.",
    "And mine is 123-456-7890, US format.",
    "They asked me to verify using +44 7700 900123.",
    "My new number is +61 412 345 678.",
    "Customer care number: 1800-233-4455.",
    "Cool. OTP came from +49 1522 3344556.",
    "Raise a ticket at service-request@helpnow.io.",
    "Save my mail: natsuki.work@jp-mail.jp.",
    "Call 1-800-555-0000 for immediate help.",
    "Updated. My mail is ahmed_trader@uaeconnect.ae.",
    "Check your inbox — paris.store@boutique.fr sent confirmation.",
    "I emailed them at tech.fix@supporters.net.",
    "My phone is formatted weird: +1(202).555.0148.",
    "Okay, message me on contact_me_fast@protonmail.com.",
    "And they called from 040 6622 1188.",""
]

# %%
import re

# %%
pattern='\d{10}'
matching=[]
for text in A+B:
    found=re.findall(pattern,text)
    matching.extend(found)

print(matching)
# Out:
# ['9876543210']
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\HP\AppData\Local\Temp\ipykernel_352\532799774.py:1: SyntaxWarning: invalid escape sequence '\d'
#   pattern='\d{10}'

# %%
# 1. Initialize
prep = ABIDEDataPreparation(
    phenotypic_file='ABIDE_II_phenotypic.csv',
    head_motion_file='ABIDE_II_head_motion.csv'  # Optional
)

# 2. Run pipeline
prep.apply_quality_filters(motion_threshold=0.3)
prep.assign_groups()
prep.match_groups(n_per_group_per_site=15)

# 3. Validate and save
prep.validate_matching()
prep.generate_demographic_table(save_path='Table1.csv')
prep.save_matched_cohort('matched_cohort.csv')
